# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjuArch/Data-Visualization/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Data Manipulation and Analysis**
#
# process:organize/arrange data - easy to interpret
#
# extract info+apply logic -> generate o/p
#
# DataFrame Libraries : Pandas , Polars

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Pandas***
#
# - work with datasets
# - lastest version - 2.0.0
# - provides tools for data manipulation - analyze/clean/explore/manipulate
#
# - Initial release : 11-01-2004
# - Highlights:
#
# *Syntactically appealing
#
# *High performance (simple queries)

# %% [markdown]
# ***Polars***
#
# - completely written in Rust
# - lastest version - 0.17.0
# - lightning-fast lib
# - handle data frames significantly more quickly than Pandas - large datasets
# - Highlights:
#
# *Built-in support for Rust (Faster in R than py)
#
# *Mem efficiency (cache + reuse mem alloc)
#
# *Parallelization (multithreading + can be exe in ||el on multiple CPU cores)
#
# *Python for interface (easy-to-use interface for data processing while leveraging(^) performance)
#
# *Lazy evalution(2 API : Lazy evalution (req) + Eager evalution (imm))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Library for Data Manipulation : Pandas
#
# Library for Scientific Computing : Numpy
#
# Libraries for visualizing Data....
# * Matplotlib
# * Seaborn
# * Bokeh
# * Plotly

# %% [markdown]
# PANDAS-BASICS
# * head()
# * tail()
# * describe()
# * dtypes
# * dinfo()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#IMPORTING DATA
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Dataset/tips.csv")
"""OR U CAN COPY THE PATH OF UR CSV FILE IN A VARIABLE (WILL SHOW LATER)"""

# %%
#ANALYZING DATA
display(df.head(10))
display(df.tail())
display(df.describe())
display(df.dtypes)
display(df.info())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# ...

# %%
#CORRELATION
df.corr()
# Out:
# <ipython-input-88-d5e974e15737>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# **DATA CLEANING:**
#
# - fixing bad data in data set.
#
# *Bad data:*
#
# * Empty cells - dropna() [return w/o] ,dropna(inplace = True) [remove]
#
# * Data in wrong format - to_datetime() [conversion], df.dropna(subset=['Date'], inplace = True) [remove]
#
# * Wrong data - df.loc[7, 'Duration'] = 45 [Replace], df.drop(x, inplace = True)[remove]
#
# * Duplicates - df.drop_duplicates(inplace = True) [remove], print(df.duplicated())[returns T if dup]

# %% [markdown]
# ### ***NUMPY***

# %% [markdown]
# ***`Installation`***
#
# pip install numpy

# %%
import numpy as np
a=np.array([10,20,30,40])
print(type(a))
print(a[0])
print(a[1:3])
b=np.array([[10,20,30],[40,50,60]])
print(type(b))
print(b[0])
print(b[1,2])
c=np.arange(10,20,2)
print(c)
d=np.random.randint(1,100,5)
print(d)
print(a.shape)
print(b.shape)
a.shape=(2,2)
print(a)
print(np.sum(c))
print("Arrays...")
print(c)
print(d)
print("Summation...")
print(np.sum([c,d],axis=0))
print(np.sum([c,d],axis=1))
print(np.intersect1d(c,d))
print(np.setdiff1d(c,d))
c=c/2
print(c)
np.mean(c)
np.median(c)
np.std(c)
np.save('sample',c)
e=np.load('sample.npy')
print(e)
# Out:
# <class 'numpy.ndarray'>
# 10
# [20 30]
# <class 'numpy.ndarray'>
# [10 20 30]
# 60
# [10 12 14 16 18]
# [26 35  1  5 98]
# (4,)
# (2, 3)
# [[10 20]
#  [30 40]]
# 70
# Arrays...
# [10 12 14 16 18]
# [26 35  1  5 98]
# Summation...
# [ 36  47  15  21 116]
# [ 70 165]
# []
# [10 12 14 16 18]
# [5. 6. 7. 8. 9.]
# [5. 6. 7. 8. 9.]

# %% [markdown]
# ### ***MATPLOTLIB***

# %% [markdown]
# ***`Installation`***
#
# pip install matplotlib

# %% [markdown]
# Resource to study matplotlib...
#
# https://matplotlib.org/stable/users/getting_started/

# %% [markdown]
# Here I have used the database tips.csv for visualizing the data...
# It is the record of the tips given by customers in a restaurant
# Duaration : two and a half years
# Columns : total_bill, tip, sex, smoker, day, time, size.
# Drive link for the csv file : https://drive.google.com/file/d/1CsJ0pjXkd9GMkcI3QDfyjdZs_E9X3Yvw/view?usp=drive_link

# %%
path="/content/drive/MyDrive/Dataset/tips.csv"

# %% [markdown]
# *SCATTER PLOT:*

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
data = pd.read_csv(path)

# %%
plt.scatter(data['day'], data['tip']) # Plotting
plt.title("Scatter Plot") # Title
plt.xlabel('Day') #Labels Setting
plt.ylabel('Tip')
plt.show() #Display

# %%
plt.scatter(data['day'], data['tip'], c=data['size'],s=data['total_bill'])
plt.title("Scatter Plot") # Title
plt.xlabel('Day') #Labels Setting
plt.ylabel('Tip')
plt.colorbar() #Scale
plt.show() #Display

# %% [markdown]
# *Line chart*

# %%
plt.plot(data['tip']) # Plotting
plt.plot(data['size'])
plt.title("Line Plot") # Title
plt.xlabel('Day') #Labels Setting
plt.ylabel('Tip')
plt.show() #Display

# %% [markdown]
# *Bar Chart*

# %%
plt.bar(data['day'], data['tip'])
plt.title("Bar Chart") # Title
plt.xlabel('Day') #Labels Setting
plt.ylabel('Tip')
plt.show() #Display

# %% [markdown]
# *Histogram*

# %%
plt.hist(data['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### ***SEABORN***

# %% [markdown]
# Resource to study seaborn...
#
# https://seaborn.pydata.org/generated/seaborn.relplot.html

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
data='/content/drive/MyDrive/Dataset/Test.csv'
weather = pd.read_csv(data)

# %%
weather.head()
# Out:
#           date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  18-05-2017 00:00       None                 73.0      63.0         1.0
# 1  18-05-2017 00:00       None                251.0      63.0         1.0
# 2  18-05-2017 00:00       None                 75.0      56.0         1.0
# 3  18-05-2017 01:00       None                 98.0      56.0         1.0
# 4  18-05-2017 01:00       None                283.0      56.0         1.0
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0            27.0                  4.0        4.0       285.15       0.0
# 1            27.0                  4.0        4.0       285.15       0.0
# 2             0.0                  1.0        1.0       285.15       0.0
# 3           351.0                  2.0        2.0       284.79       0.0
# 4           351.0                  1.0        1.0       284.79       0.0
#
#    snow_p_h  clouds_all weather_type      weather_description
# ...

# %% [markdown]
# *Barplot*

# %%
sns.barplot(data=weather,x='humidity',y='temperature')
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %%
sns.barplot(data=weather, x="humidity", y="temperature",hue="weather_type")
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %% [markdown]
# *Histogram*

# %%
sns.histplot(data=weather, x="humidity",hue="weather_type",kde=True)
# Out:
# <Axes: xlabel='humidity', ylabel='Count'>

# %% [markdown]
# *Distplot*

# %%
sns.distplot(weather['humidity'], kde=False, rug=True);
# Out:
# <ipython-input-11-0ba66e98cb3f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(weather['humidity'], kde=False, rug=True);

# %% [markdown]
# *Joinplot*

# %%
sns.jointplot(data=weather,x='humidity',y='temperature')

# %%
sns.jointplot(data=weather,x='humidity', y='temperature', kind="hex")

# %% [markdown]
# *Pairplot*

# %%
sns.pairplot(weather[['humidity', 'temperature', 'air_pollution_index']])

# %% [markdown]
# *Lineplot*

# %%
sns.lineplot(x='weather_type',y='temperature',data=weather)
plt.title('Lineplot')
plt.show()

# %%
sns.lineplot(x='weather_type',y='temperature',data=weather)
plt.title('Lineplot')
plt.show()

# %% [markdown]
# *Stripplot*

# %%
sns.lineplot(data=weather.drop(['weather_type'],axis=1))
# Out:
# <Axes: >

# %%
sns.stripplot(data=weather,x='weather_type', y='temperature', jitter = True)
# Out:
# <Axes: xlabel='weather_type', ylabel='temperature'>

# %% [markdown]
# *Swarmplot*

# %%
sns.swarmplot(data=weather,x='humidity', y='temperature')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# *Boxplot*

# %%
sns.boxplot(data=weather,x='humidity', y='temperature', hue='weather_type')
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %% [markdown]
# *Countplot*

# %%
sns.countplot(data=weather,x='weather_type')
# Out:
# <Axes: xlabel='weather_type', ylabel='count'>

# %%
sns.countplot(data=weather,y='weather_type')
# Out:
# <Axes: xlabel='count', ylabel='weather_type'>

# %% [markdown]
# *Pointplot*

# %%
sns.pointplot(data=weather,x='humidity',y='temperature', hue='weather_type')
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %% [markdown]
# *Lmplot*

# %%
sns.lmplot(x="humidity", y="temperature", data=weather)

# %%
sns.lmplot(x="humidity", y="temperature", hue="weather_type", data=weather)

# %% [markdown]
# *Scatterplot...*

# %%
sns.scatterplot(data=weather, x="humidity", y="temperature")
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %%
sns.scatterplot(data=weather, x="humidity", y="temperature",hue="weather_type")
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %%
sns.scatterplot(data=weather, x="humidity", y="temperature",hue="weather_type",style="weather_type")
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %%
sns.scatterplot(data=weather, x="humidity", y="temperature", hue="weather_type", style="visibility_in_miles")
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %% [markdown]
# ## *Plotly*

# %% [markdown]
# Resource to study plotly...
#
# https://plotly.com/python/plot-data-from-csv/
#
#
# https://notebooks.gesis.org/binder/jupyter/user/bokeh-bokeh-notebooks-h53cn2vc/notebooks/tutorial/00%20-%20Introduction%20and%20Setup.ipynb

# %%
import plotly.express as px

# %% [markdown]
# *Scatter Plot*

# %%
fig = px.scatter(data, x="day", y="tip", color='sex')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# *Line chart*

# %%
fig=px.line(data,y='tip',color='sex')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# *Bar Chart*

# %%
fig = px.bar(data, x='day', y='tip', color='sex')
fig.show()

# %% [markdown]
# *Histogram*

# %%
fig = px.histogram(data, x='total_bill', color='sex')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# *Interactive designs*

# %%
import plotly.graph_objects as px
plot = px.Figure(data=[px.Scatter(x=data['day'],y=data['tip'],mode='markers',)])
plot.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=["type", "scatter"],
                    label="Scatter Plot",
                    method="restyle"
                ),
                dict(
                    args=["type", "bar"],
                    label="Bar Chart",
                    method="restyle"
                )
            ]),
            direction="down",
        ),
    ]
)

plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as px
plot = px.Figure(data=[px.Scatter(x=data['day'],y=data['tip'],mode='markers',)])
plot.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            direction="left",
            buttons=list([
                dict(
                    args=["type", "scatter"],
                    label="Scatter Plot",
                    method="restyle"
                ),
                dict(
                    args=["type", "bar"],
                    label="Bar Chart",
                    method="restyle"
                )
            ]),
        ),
    ]
)

plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as px
plot = px.Figure(data=[px.Scatter(y=data['tip'],mode='lines',)])
plot.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                    step="day",
                    stepmode="backward"),
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
    )
)

plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
